# %%
# Dependencies
import numpy as np
import pandas as pd
from census import Census
from us import states
import requests

# Census API Key
c = Census("85ac64b6b5a9c0901b00329d1ef41f0c53ccfc98", year=2015)

# %%
# Retrieve Census Data (Reference: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b)
zip_census = c.acs5.get(( "B19013_001E",
                          "B19301_001E",
                          "B15003_002E",
                          "B15003_017E",
                          "B15003_018E",
                          "B15003_022E",
                          "B15003_021E",
                          "B15003_023E",
                          "B15003_024E",
                          "B15003_025E",
                          "B17001_002E",
                          "B23025_002E",
                          "B23025_005E",
                          "B01002_001E",
                          "B01002_002E",
                          "B01002_003E",
                          "B01003_001E",
                          "B25064_001E",
                          "B25077_001E",
                          "B25077_001E",
                          "B02001_002E",
                          "B02001_003E",
                          "B02001_004E",
                          "B02001_005E",
                          "B03001_003E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
zip_census = pd.DataFrame(zip_census)

# Column Reordering
zip_census = zip_census.rename(columns={"B19013_001E": "Household Income", 
                                      "B19301_001E": "Income Per Capita",
                                      "B15003_002E": "Education None",
                                      "B15003_017E": "Education High School",
                                      "B15003_018E": "Education GED",
                                      "B15003_022E": "Education Bachelors",
                                      "B15003_021E": "Education Associates",
                                      "B15003_023E": "Education Masters",
                                      "B15003_024E": "Education Professional",
                                      "B15003_025E": "Education Doctorate",
                                      "B17001_002E": "Poverty",
                                      "B23025_002E": "Employment Labor Force",
                                      "B23025_005E": "Employment Unemployed",
                                      "B01002_001E": "Median Age",
                                      "B01002_002E": "Median Male Age",
                                      "B01002_003E": "Median Female Age",
                                      "B01003_001E": "Population",
                                      "B25064_001E": "Median Gross Rent",
                                      "B25077_001E": "Median Home Value",
                                      "B02001_002E": "White Population",
                                      "B02001_003E": "Black Population",
                                      "B02001_004E": "Native American Population",
                                      "B02001_005E": "Asian Population",
                                      "B03001_003E": "Hispanic Population",
                                      "zip code tabulation area": "zipcode"})

# Visualize Data
zip_census.head()
# Out:
#   Median Age Median Male Age Median Female Age Population White Population  \
# 0       37.6            36.5                39      17982            16956
# 1       39.5            38.6              40.3      40260            23144
# 2       39.9            37.7              41.4      52408            36177
# 3       40.8              41              40.3       6331             4399
# 4       40.2            36.9              42.2      28328            17791
#
#   Black Population Native American Population Asian Population  \
# 0              102                         14                0
# 1              693                          8               72
# 2             2057                         76              655
# 3              151                          0                0
# 4              950                          0               26
#
#   Hispanic Population Education None   ...   Education Professional  \
# 0               17942            456   ...                       59
# 1               37681            955   ...                      206
# 2               50437           1014   ...                      283
# 3                6323            188   ...                       17
# 4               27999            377   ...                       38
#
#   Education Doctorate Poverty Household Income Income Per Capita  \
# 0                  65   10861            10816              7453
# 1                 258   21720            16079              8474
# 2                 280   25459            16804             10179
# 3                  32    4070            12512              5863
# 4                 144   14005            17475              8452
#
#   Employment Labor Force Employment Unemployed Median Gross Rent  \
# 0                   6162                  2213               359
# 1                  15289                  3807               395
# 2                  17058                  3991               384
# 3                   1679                   179               280
# 4                   9542                  1495               424
#
#   Median Home Value zipcode
# 0            104500   00601
# 1             90200   00602
# 2            128400   00603
# 3            108500   00606
# 4            113200   00610
#
# [5 rows x 25 columns]

# %%
# Geocode
zip_lat_lng = pd.read_excel("../Raw/Latitude_Longitude_Zip.xlsx", converters={"zipcode": str})
zip_lat_lng.head()
# Out:
#   zipcode        lat        lng       city state
# 0   00601  18.180555 -66.749961   ADJUNTAS    PR
# 1   00602  18.361945 -67.175597     AGUADA    PR
# 2   00603  18.455183 -67.119887  AGUADILLA    PR
# 3   00606  18.158345 -66.932911    MARICAO    PR
# 4   00610  18.295366 -67.125135     ANASCO    PR

# %%
# Merge Data
zip_census_geocoded = zip_census.merge(zip_lat_lng, on="zipcode", how="left")
zip_census_geocoded.head()
# Out:
#   Median Age Median Male Age Median Female Age Population White Population  \
# 0       37.6            36.5                39      17982            16956
# 1       39.5            38.6              40.3      40260            23144
# 2       39.9            37.7              41.4      52408            36177
# 3       40.8              41              40.3       6331             4399
# 4       40.2            36.9              42.2      28328            17791
#
#   Black Population Native American Population Asian Population  \
# 0              102                         14                0
# 1              693                          8               72
# 2             2057                         76              655
# 3              151                          0                0
# 4              950                          0               26
#
#   Hispanic Population Education None  ...  Income Per Capita  \
# 0               17942            456  ...               7453
# 1               37681            955  ...               8474
# 2               50437           1014  ...              10179
# 3                6323            188  ...               5863
# 4               27999            377  ...               8452
#
#   Employment Labor Force Employment Unemployed Median Gross Rent  \
# 0                   6162                  2213               359
# 1                  15289                  3807               395
# 2                  17058                  3991               384
# 3                   1679                   179               280
# 4                   9542                  1495               424
#
#   Median Home Value zipcode        lat        lng       city state
# 0            104500   00601  18.180555 -66.749961   ADJUNTAS    PR
# 1             90200   00602  18.361945 -67.175597     AGUADA    PR
# 2            128400   00603  18.455183 -67.119887  AGUADILLA    PR
# 3            108500   00606  18.158345 -66.932911    MARICAO    PR
# 4            113200   00610  18.295366 -67.125135     ANASCO    PR
#
# [5 rows x 29 columns]

# %%
# Filter to a State
zip_data = zip_census_geocoded[zip_census_geocoded["state"] == "WV"]

# %%
# Build URLs
max_distance_meters = 8000
city_amenity = "Hosptial"
gkey = "{API KEY}"
zip_data["Google_URL"] = "https://maps.googleapis.com/maps/api/place/radarsearch/json?location=" + zip_census_geocoded["lat"].map(str) + "," + zip_census_geocoded["lng"].map(str) + "&radius=" + str(max_distance_meters) + "&keyword=" + city_amenity + "&key=" + gkey
# Out:
# /Users/afhaque/anaconda/envs/PythonData/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
zip_data.head()
# Out:
#      Median Age Median Male Age Median Female Age Population White Population  \
# 7633       43.3            42.3              44.3      20891            17585
# 7634       23.6            22.7              33.2       2007             1842
# 7635       35.2              36              23.4        127              127
# 7636       52.4              60              47.8        366              359
# 7637       54.3            55.2                52        460              364
#
#      Black Population Native American Population Asian Population  \
# 7633             2852                         31               98
# 7634              113                          0               13
# 7635                0                          0                0
# 7636                6                          0                1
# 7637               96                          0                0
#
#      Hispanic Population Education None  \
# 7633                 116            142
# 7634                  32              0
# 7635                   0              8
# 7636                   0              2
# 7637                   0              0
#
#                             ...                          \
# 7633                        ...
# 7634                        ...
# 7635                        ...
# 7636                        ...
# 7637                        ...
#
#      Employment Labor Force Employment Unemployed Median Gross Rent  \
# 7633                   8176                   437               565
# 7634                    781                    51               635
# 7635                     37                    11              None
# 7636                    103                     2               570
# 7637                    148                    10              None
#
#      Median Home Value zipcode        lat        lng       city state  \
# 7633             66300   24701  37.305951 -81.204941  BLUEFIELD    WV
# 7634            124500   24712  37.463059 -81.015010     ATHENS    WV
# 7635             82600   24714  37.484469 -81.190073     BEESON    WV
# 7636             63800   24715  37.340392 -81.324618   BRAMWELL    WV
# 7637              None   24716  37.480042 -81.371826        BUD    WV
#
#                                              Google_URL
# 7633  https://maps.googleapis.com/maps/api/place/rad...
# 7634  https://maps.googleapis.com/maps/api/place/rad...
# 7635  https://maps.googleapis.com/maps/api/place/rad...
# 7636  https://maps.googleapis.com/maps/api/place/rad...
# 7637  https://maps.googleapis.com/maps/api/place/rad...
#
# [5 rows x 30 columns]

# %%
# Sample Test
test_run = zip_data.sample(n=15)
test_run["Count"] = ""

# Loop through and run Google search to get counts for each record 
for index, row in test_run.iterrows():

        # Create endpoint url using Google Places Radar and the lat/lng we identified earlier
        target_url ="https://maps.googleapis.com/maps/api/place/radarsearch/json?location=%s,%s&radius=8000&type=bank&key=%s" % (test_run.loc[index]["lat"], test_run.loc[index]["lng"], gkey)

        # This link helps to handily see the JSON generated for each query
        print("Now retrieving city #%s: %s" % (row_count, test_run.loc[index]["zipcode"]))
        row_count += 1 
        print(target_url)

        # Run a request to grab the JSON at the target URL
        radar_data = requests.get(target_url).json()

        # Measure radar_data count on the number of results in the retrieved area
        count = len(radar_data["results"])

        print("Final Count: " + str(count))
        print("")

        # Store the bank count into the Data Frame
        test_run.set_value(index, "Count", count)

        # Reset bank_count (so there is no chance that a previous record is influencing a latter one)
        count = 0

        # Add to Row Count for test             
        row_count = row_count + 1


# Visualize
test_run.head()
# Out:
# Now retrieving city #405: 26104
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.276141,-81.480363&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 34
#
# Now retrieving city #407: 25102
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.191015,-81.374818&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 3
#
# Now retrieving city #409: 26152
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.010062,-81.195907&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 0
#
# Now retrieving city #411: 25082
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.604207,-82.031043&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 1
#
# Now retrieving city #413: 26376
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.784372,-80.453871&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 0
#
# Now retrieving city #415: 25414
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.242415,-77.865749&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 12
#
# Now retrieving city #417: 25611
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.688915,-81.840825&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 3
#
# Now retrieving city #419: 25245
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.69742,-81.755385&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 0
#
# Now retrieving city #421: 24910
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.750526,-80.648133&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 1
#
# Now retrieving city #423: 25564
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.272188,-81.901012&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 1
#
# Now retrieving city #425: 25113
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.553281,-81.046284&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 0
#
# Now retrieving city #427: 25143
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.417874,-81.819479&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 14
#
# Now retrieving city #429: 25696
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.679044,-82.115919&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 4
#
# Now retrieving city #431: 25571
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.313493,-82.155813&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 5
#
# Now retrieving city #433: 25832
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.715324,-81.118819&radius=8000&type=bank&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# Final Count: 5
#      Median Age Median Male Age Median Female Age Population White Population  \
# 8095       43.3            41.3              45.7      16530            16016
# 7784       32.4            32.4              32.5        301              237
# 8111       53.5            53.2              54.2        148              148
# 7777       33.9            33.7              35.1       1686             1686
# 8201         45            44.5              47.7        481              481
#
#      Black Population Native American Population Asian Population  \
# 8095               83                         14               60
# 7784                4                          0                0
# 8111                0                          0                0
# 7777                0                          0                0
# 8201                0                          0                0
#
#      Hispanic Population Education None  ...  Employment Unemployed  \
# 8095                 198             78  ...                    440
# 7784                  10              1  ...                      4
# 8111                   0              0  ...                      0
# 7777                   9              0  ...                     97
# 8201                   0              0  ...                     27
#
#      Median Gross Rent Median Home Value zipcode        lat        lng  \
# 8095               653            102300   26104  39.276141 -81.480363
# 7784               656             55400   25102  38.191015 -81.374818
# 8111              None              None   26152  39.010062 -81.195907
# 7777               609              None   25082  38.604207 -82.031043
# 8201              None             34400   26376  38.784372 -80.453871
#
#                  city state  \
# 8095      PARKERSBURG    WV
# 7784          HANDLEY    WV
# 8111           MUNDAY    WV
# 7777  FRAZIERS BOTTOM    WV
# 8201          IRELAND    WV
#
#                                              Google_URL Count
# 8095  https://maps.googleapis.com/maps/api/place/rad...    34
# 7784  https://maps.googleapis.com/maps/api/place/rad...     3
# 8111  https://maps.googleapis.com/maps/api/place/rad...     0
# 7777  https://maps.googleapis.com/maps/api/place/rad...     1
# 8201  https://maps.googleapis.com/maps/api/place/rad...     0
#
# [5 rows x 31 columns]
