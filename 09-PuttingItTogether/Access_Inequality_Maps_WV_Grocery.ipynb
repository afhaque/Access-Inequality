# %% [markdown]
# # Access Inequality Maps
# ---
# The below script allows us to quickly uncover zip codes that lack access to common amenities (supermarkets, banks, schools, hospitals, etc). The script retrieves data from the 2015 US Census, Google Distance Matrix API, and Google Radar API to identify the number of such amenities and distance to the neareset one. The final dataset can be easily mapped or correlated against demographic information.

# %% [markdown]
# ### Dependencies

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time 
from census import Census
from us import states
from requests_toolbelt.threaded import pool
from multiprocessing.pool import ThreadPool

# %%
# Census API Key
c = Census("85ac64b6b5a9c0901b00329d1ef41f0c53ccfc98", year=2015)

# Google API Key
gkey = "{API KEY}"

# %% [markdown]
# ### Parameters

# %%
# Required Parameter
max_distance_meters = 40233
city_amenity = "Grocery"

# Optional Parameters
restrict_to_state = True
state = "WV"

# %% [markdown]
# ### Retrieve Census Data

# %%
# Retrieve Census Data (Reference: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b)
zip_census = c.acs5.get(( "B19013_001E",
                          "B19301_001E",
                          "B15003_002E",
                          "B15003_017E",
                          "B15003_018E",
                          "B15003_022E",
                          "B15003_021E",
                          "B15003_023E",
                          "B15003_024E",
                          "B15003_025E",
                          "B17001_002E",
                          "B23025_002E",
                          "B23025_005E",
                          "B01002_001E",
                          "B01002_002E",
                          "B01002_003E",
                          "B01003_001E",
                          "B25064_001E",
                          "B25077_001E",
                          "B25077_001E",
                          "B02001_002E",
                          "B02001_003E",
                          "B02001_004E",
                          "B02001_005E",
                          "B03001_003E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
zip_census = pd.DataFrame(zip_census)

# Column Reordering
zip_census = zip_census.rename(columns={"B19013_001E": "Household Income", 
                                      "B19301_001E": "Income Per Capita",
                                      "B15003_002E": "Education None",
                                      "B15003_017E": "Education High School",
                                      "B15003_018E": "Education GED",
                                      "B15003_022E": "Education Bachelors",
                                      "B15003_021E": "Education Associates",
                                      "B15003_023E": "Education Masters",
                                      "B15003_024E": "Education Professional",
                                      "B15003_025E": "Education Doctorate",
                                      "B17001_002E": "Poverty",
                                      "B23025_002E": "Employment Labor Force",
                                      "B23025_005E": "Employment Unemployed",
                                      "B01002_001E": "Median Age",
                                      "B01002_002E": "Median Male Age",
                                      "B01002_003E": "Median Female Age",
                                      "B01003_001E": "Population",
                                      "B25064_001E": "Median Gross Rent",
                                      "B25077_001E": "Median Home Value",
                                      "B02001_002E": "White Population",
                                      "B02001_003E": "Black Population",
                                      "B02001_004E": "Native American Population",
                                      "B02001_005E": "Asian Population",
                                      "B03001_003E": "Hispanic Population",
                                      "zip code tabulation area": "zipcode"})

# Visualize Data
zip_census.head()
# Out:
#   Median Age Median Male Age Median Female Age Population White Population  \
# 0       37.6            36.5                39      17982            16956
# 1       39.5            38.6              40.3      40260            23144
# 2       39.9            37.7              41.4      52408            36177
# 3       40.8              41              40.3       6331             4399
# 4       40.2            36.9              42.2      28328            17791
#
#   Black Population Native American Population Asian Population  \
# 0              102                         14                0
# 1              693                          8               72
# 2             2057                         76              655
# 3              151                          0                0
# 4              950                          0               26
#
#   Hispanic Population Education None   ...   Education Professional  \
# 0               17942            456   ...                       59
# 1               37681            955   ...                      206
# 2               50437           1014   ...                      283
# 3                6323            188   ...                       17
# 4               27999            377   ...                       38
#
#   Education Doctorate Poverty Household Income Income Per Capita  \
# 0                  65   10861            10816              7453
# 1                 258   21720            16079              8474
# 2                 280   25459            16804             10179
# 3                  32    4070            12512              5863
# 4                 144   14005            17475              8452
#
#   Employment Labor Force Employment Unemployed Median Gross Rent  \
# 0                   6162                  2213               359
# 1                  15289                  3807               395
# 2                  17058                  3991               384
# 3                   1679                   179               280
# 4                   9542                  1495               424
#
#   Median Home Value zipcode
# 0            104500   00601
# 1             90200   00602
# 2            128400   00603
# 3            108500   00606
# 4            113200   00610
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Retrieve Geocode Data

# %%
zip_lat_lng = pd.read_excel("../../Raw/Latitude_Longitude_Zip.xlsx", converters={"zipcode": str})
zip_lat_lng.head()
# Out:
#   zipcode        lat        lng       city state
# 0   00601  18.180555 -66.749961   ADJUNTAS    PR
# 1   00602  18.361945 -67.175597     AGUADA    PR
# 2   00603  18.455183 -67.119887  AGUADILLA    PR
# 3   00606  18.158345 -66.932911    MARICAO    PR
# 4   00610  18.295366 -67.125135     ANASCO    PR

# %%
zip_census_geocoded = zip_census.merge(zip_lat_lng, on="zipcode", how="left")
zip_census_geocoded.head()
# Out:
#   Median Age Median Male Age Median Female Age Population White Population  \
# 0       37.6            36.5                39      17982            16956
# 1       39.5            38.6              40.3      40260            23144
# 2       39.9            37.7              41.4      52408            36177
# 3       40.8              41              40.3       6331             4399
# 4       40.2            36.9              42.2      28328            17791
#
#   Black Population Native American Population Asian Population  \
# 0              102                         14                0
# 1              693                          8               72
# 2             2057                         76              655
# 3              151                          0                0
# 4              950                          0               26
#
#   Hispanic Population Education None  ...  Income Per Capita  \
# 0               17942            456  ...               7453
# 1               37681            955  ...               8474
# 2               50437           1014  ...              10179
# 3                6323            188  ...               5863
# 4               27999            377  ...               8452
#
#   Employment Labor Force Employment Unemployed Median Gross Rent  \
# 0                   6162                  2213               359
# 1                  15289                  3807               395
# 2                  17058                  3991               384
# 3                   1679                   179               280
# 4                   9542                  1495               424
#
#   Median Home Value zipcode        lat        lng       city state
# 0            104500   00601  18.180555 -66.749961   ADJUNTAS    PR
# 1             90200   00602  18.361945 -67.175597     AGUADA    PR
# 2            128400   00603  18.455183 -67.119887  AGUADILLA    PR
# 3            108500   00606  18.158345 -66.932911    MARICAO    PR
# 4            113200   00610  18.295366 -67.125135     ANASCO    PR
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Filter Data by State

# %%
# Apply filter if user wishes
if restrict_to_state:
    zip_data = zip_census_geocoded[zip_census_geocoded["state"] == state]
else:
    state = "USA"

# %%
zip_data.head()
# Out:
#      Median Age Median Male Age Median Female Age Population White Population  \
# 7633       43.3            42.3              44.3      20891            17585
# 7634       23.6            22.7              33.2       2007             1842
# 7635       35.2              36              23.4        127              127
# 7636       52.4              60              47.8        366              359
# 7637       54.3            55.2                52        460              364
#
#      Black Population Native American Population Asian Population  \
# 7633             2852                         31               98
# 7634              113                          0               13
# 7635                0                          0                0
# 7636                6                          0                1
# 7637               96                          0                0
#
#      Hispanic Population Education None  ...  Income Per Capita  \
# 7633                 116            142  ...              19285
# 7634                  32              0  ...              18581
# 7635                   0              8  ...              13413
# 7636                   0              2  ...              18980
# 7637                   0              0  ...              24869
#
#      Employment Labor Force Employment Unemployed Median Gross Rent  \
# 7633                   8176                   437               565
# 7634                    781                    51               635
# 7635                     37                    11              None
# 7636                    103                     2               570
# 7637                    148                    10              None
#
#      Median Home Value zipcode        lat        lng       city state
# 7633             66300   24701  37.305951 -81.204941  BLUEFIELD    WV
# 7634            124500   24712  37.463059 -81.015010     ATHENS    WV
# 7635             82600   24714  37.484469 -81.190073     BEESON    WV
# 7636             63800   24715  37.340392 -81.324618   BRAMWELL    WV
# 7637              None   24716  37.480042 -81.371826        BUD    WV
#
# [5 rows x 29 columns]

# %%
zip_data.count()
# Out:
# Median Age                    696
# Median Male Age               688
# Median Female Age             687
# Population                    706
# White Population              706
# Black Population              706
# Native American Population    706
# Asian Population              706
# Hispanic Population           706
# Education None                706
# Education High School         706
# Education GED                 706
# Education Associates          706
# Education Bachelors           706
# Education Masters             706
# Education Professional        706
# Education Doctorate           706
# Poverty                       706
# Household Income              621
# Income Per Capita             695
# Employment Labor Force        706
# Employment Unemployed         706
# Median Gross Rent             380
# Median Home Value             604
# zipcode                       706
# lat                           706
# lng                           706
# city                          706
# state                         706
# dtype: int64

# %% [markdown]
# ### Create Query URLs

# %%
zip_data["Google_URL"] = "https://maps.googleapis.com/maps/api/place/radarsearch/json?location=" + zip_data["lat"].map(str) + "," + state_data["lng"].map(str) + "&radius=" + str(max_distance_meters) + "&keyword=" + city_amenity + "&key=" + gkey
# Out:
# /Users/afhaque/anaconda/envs/PythonData/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
zip_data.head()
# Out:
#      Median Age Median Male Age Median Female Age Population White Population  \
# 7633       43.3            42.3              44.3      20891            17585
# 7634       23.6            22.7              33.2       2007             1842
# 7635       35.2              36              23.4        127              127
# 7636       52.4              60              47.8        366              359
# 7637       54.3            55.2                52        460              364
#
#      Black Population Native American Population Asian Population  \
# 7633             2852                         31               98
# 7634              113                          0               13
# 7635                0                          0                0
# 7636                6                          0                1
# 7637               96                          0                0
#
#      Hispanic Population Education None  \
# 7633                 116            142
# 7634                  32              0
# 7635                   0              8
# 7636                   0              2
# 7637                   0              0
#
#                             ...                          \
# 7633                        ...
# 7634                        ...
# 7635                        ...
# 7636                        ...
# 7637                        ...
#
#      Employment Labor Force Employment Unemployed Median Gross Rent  \
# 7633                   8176                   437               565
# 7634                    781                    51               635
# 7635                     37                    11              None
# 7636                    103                     2               570
# 7637                    148                    10              None
#
#      Median Home Value zipcode        lat        lng       city state  \
# 7633             66300   24701  37.305951 -81.204941  BLUEFIELD    WV
# 7634            124500   24712  37.463059 -81.015010     ATHENS    WV
# 7635             82600   24714  37.484469 -81.190073     BEESON    WV
# 7636             63800   24715  37.340392 -81.324618   BRAMWELL    WV
# 7637              None   24716  37.480042 -81.371826        BUD    WV
#
#                                              Google_URL
# 7633  https://maps.googleapis.com/maps/api/place/rad...
# 7634  https://maps.googleapis.com/maps/api/place/rad...
# 7635  https://maps.googleapis.com/maps/api/place/rad...
# 7636  https://maps.googleapis.com/maps/api/place/rad...
# 7637  https://maps.googleapis.com/maps/api/place/rad...
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Perform API Calls (Multi-Threaded Approach)

# %%
# Make API Calls
p = pool.Pool.from_urls(zip_data["Google_URL"].values, num_processes=35)
p.join_all()

# %% [markdown]
# ### Combine With Original Data

# %%
# Array to hold all retrieved data
amenity_counts = []

# Loop through pooled results
for response in p.responses():
    print(response.request_kwargs['url'])
    print(len(response.json()["results"]))
    count = {
        "Google_URL": response.request_kwargs['url'],
        "Count": len(response.json()["results"])
    }
    amenity_counts.append(count)
    
full_data = pd.DataFrame(amenity_counts)
# Out:
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.352268,-81.80478&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 81
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.399166,-81.771251&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 86
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.293267,-81.623592&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 97
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.357412,-81.720113&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 88
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.333874,-81.55862&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 116
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.305951,-81.204941&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 132
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.340392,-81.324618&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 131
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.394105,-81.411521&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 133
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.484469,-81.190073&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 170
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.449867,-81.26001&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 157
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.67197,-81.751948&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 77
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.75327,-81.64148&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 100
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.330881,-81.299757&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 129
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.602702,-81.624946&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 117
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.514751,-81.352074&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 133
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.323125,-81.506122&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 116
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.487167,-81.326725&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 141
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.330026,-81.422403&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 135
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.560676,-81.738389&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 82
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.461102,-81.705939&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 87
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.241667,-81.659603&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 132
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.647094,-81.697294&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 82
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.487144,-81.7101&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 91
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.378752,-81.299696&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 139
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.444189,-81.2774&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 153
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.547689,-81.630566&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 127
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.373474,-81.005001&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 151
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.302041,-81.3097&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 135
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.463059,-81.01501&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 155
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.397966,-81.151064&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 168
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.480042,-81.371826&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 140
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.4989,-81.636635&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 115
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.352245,-81.249309&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 131
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.448883,-81.576989&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 153
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.450768,-81.205194&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 171
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.462452,-81.806627&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 69
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.529522,-81.91286&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 98
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.303745,-81.460677&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 133
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.601371,-81.833685&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 87
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.517953,-81.817841&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 90
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.469177,-81.964569&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 88
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.32097,-81.850505&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 93
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.449369,-81.920479&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 95
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.67251,-81.660302&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 87
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.577109,-81.418416&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 137
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.43845,-81.389063&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 136
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.665763,-81.542748&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 142
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.313896,-81.758686&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 81
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.465457,-79.77717&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 26
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.366148,-81.878193&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 91
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.66017,-81.607608&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 119
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.439308,-81.625265&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 112
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.562684,-81.838107&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 89
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.248133,-81.580323&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 131
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.736493,-81.572685&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 145
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.855406,-80.451557&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 75
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.595764,-81.444714&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 173
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.350951,-81.36313&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 120
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.359301,-81.468304&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 126
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.435447,-81.511823&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 171
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.625597,-81.766&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 81
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.431342,-81.684596&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 99
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.201314,-80.16489&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 49
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37.274965,-81.713671&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 94
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=37
radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 75
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.503126,-78.643193&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 142
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.885774,-78.878032&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 90
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.627463,-79.205234&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 115
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.781086,-79.475798&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 69
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.67445,-79.340618&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 77
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.271397,-78.695001&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 95
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.246727,-78.896354&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 68
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.088814,-79.220549&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 68
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.164519,-78.964204&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 75
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.166376,-78.724626&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 93
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.94914,-79.134534&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 52
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.207894,-78.457442&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 138
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.948051,-79.269009&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 46
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.318195,-78.743841&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 104
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.99824,-78.975114&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 74
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.996545,-78.753667&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 94
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.80061,-79.234329&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 69
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.452071,-79.553425&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 163
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.493516,-79.364475&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 83
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.132607,-78.464071&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 156
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=38.904902,-79.395514&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 69
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.373773,-78.401579&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 147
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.205938,-78.512135&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 135
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=39.047099,-78.611026&radius=40233&keyword=Grocery&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# 141

# %%
# Merge the Amenity count data to the original data
final_dataset = zip_data.merge(full_data, on="Google_URL", how="inner")

# %%
final_dataset.head()
# Out:
#   Median Age Median Male Age Median Female Age Population White Population  \
# 0       43.3            42.3              44.3      20891            17585
# 1       23.6            22.7              33.2       2007             1842
# 2       35.2              36              23.4        127              127
# 3       52.4              60              47.8        366              359
# 4       54.3            55.2                52        460              364
#
#   Black Population Native American Population Asian Population  \
# 0             2852                         31               98
# 1              113                          0               13
# 2                0                          0                0
# 3                6                          0                1
# 4               96                          0                0
#
#   Hispanic Population Education None  ...  Employment Unemployed  \
# 0                 116            142  ...                    437
# 1                  32              0  ...                     51
# 2                   0              8  ...                     11
# 3                   0              2  ...                      2
# 4                   0              0  ...                     10
#
#   Median Gross Rent Median Home Value zipcode        lat        lng  \
# 0               565             66300   24701  37.305951 -81.204941
# 1               635            124500   24712  37.463059 -81.015010
# 2              None             82600   24714  37.484469 -81.190073
# 3               570             63800   24715  37.340392 -81.324618
# 4              None              None   24716  37.480042 -81.371826
#
#         city state                                         Google_URL Count
# 0  BLUEFIELD    WV  https://maps.googleapis.com/maps/api/place/rad...   132
# 1     ATHENS    WV  https://maps.googleapis.com/maps/api/place/rad...   155
# 2     BEESON    WV  https://maps.googleapis.com/maps/api/place/rad...   170
# 3   BRAMWELL    WV  https://maps.googleapis.com/maps/api/place/rad...   131
# 4        BUD    WV  https://maps.googleapis.com/maps/api/place/rad...   140
#
# [5 rows x 31 columns]

# %%
final_dataset.count()
# Out:
# Median Age                    696
# Median Male Age               688
# Median Female Age             687
# Population                    706
# White Population              706
# Black Population              706
# Native American Population    706
# Asian Population              706
# Hispanic Population           706
# Education None                706
# Education High School         706
# Education GED                 706
# Education Associates          706
# Education Bachelors           706
# Education Masters             706
# Education Professional        706
# Education Doctorate           706
# Poverty                       706
# Household Income              621
# Income Per Capita             695
# Employment Labor Force        706
# Employment Unemployed         706
# Median Gross Rent             380
# Median Home Value             604
# zipcode                       706
# lat                           706
# lng                           706
# city                          706
# state                         706
# Google_URL                    706
# Count                         706
# dtype: int64

# %% [markdown]
# ### Export the Data

# %%
final_dataset.to_csv("%s-%s.csv" %(state, city_amenity))
